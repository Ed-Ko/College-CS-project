# %%
import pandas as pd

# %%
# load csv
main = pd.read_csv('main.csv')
supply = pd.read_csv('supply.csv')

# %%
# rename column
main.rename(columns={
    '時間戳記': 'timestamp',
    '性別': 'gender',
    '年齡區間': 'age',
    '就讀科/系/所': 'department',
    '每天使用手機的平均總時長': 'total_usetime',
    '對各類應用程式每天的使用時長 [社群（Facebook、Instagram...）]': 'social_usetime',
    '對各類應用程式每天的使用時長 [通訊（Line、Messenger...）]': 'communication_usetime',
    '對各類應用程式每天的使用時長 [娛樂（遊戲、Netflix、YouTube...）]': 'entertainment_usetime',
    '對各類應用程式每天的使用時長 [消息（新聞、信箱、天氣、運動）]': 'news_usetime',
    '對各類應用程式每天的使用時長 [系統通知（軟體更新、容量已滿）]': 'system_usetime',
    '對各類應用程式每天的使用時長 [提醒（鬧鈴、活動、待辦事項）]': 'notification_usetime',
    '若手機通知中心裡有六則通知，將訊息分成三區（上、中、下：每區各有兩則訊息），您看通知的順序為何？ [上區]': 'view_order_top',
    '若手機通知中心裡有六則通知，將訊息分成三區（上、中、下：每區各有兩則訊息），您看通知的順序為何？ [中區]': 'view_order_middle',
    '若手機通知中心裡有六則通知，將訊息分成三區（上、中、下：每區各有兩則訊息），您看通知的順序為何？ [下區]': 'view_order_bottom',
    
    '假設您起床時打開手機，若手機通知中心裡有6則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [社群（Facebook、Instagram...）]': 'social_order_wakingup',
    '假設您起床時打開手機，若手機通知中心裡有6則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [通訊（Line、Messenger...）]': 'communication_order_wakingup',
    '假設您起床時打開手機，若手機通知中心裡有6則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [娛樂（遊戲、Netflix、YouTube...）]': 'entertainment_order_wakingup',
    '假設您起床時打開手機，若手機通知中心裡有6則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [消息（新聞、信箱、天氣、運動）]': 'news_order_wakingup',
    '假設您起床時打開手機，若手機通知中心裡有6則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [系統通知（軟體更新、容量已滿）]': 'system_order_wakingup',
    '假設您起床時打開手機，若手機通知中心裡有6則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [提醒（鬧鈴、活動、待辦事項）]': 'notification_order_wakingup',
    
    '假設您上課/工作時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [社群（Facebook、Instagram...）]': 'social_order_working',
    '假設您上課/工作時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [通訊（Line、Messenger...）]': 'communication_order_working',
    '假設您上課/工作時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [娛樂（遊戲、Netflix、YouTube...）]': 'entertainment_order_working',
    '假設您上課/工作時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [消息（新聞、信箱、天氣、運動）]': 'news_order_working',
    '假設您上課/工作時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [系統通知（軟體更新、容量已滿）]': 'system_order_working',
    '假設您上課/工作時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [提醒（鬧鈴、活動、待辦事項）]': 'notification_order_working',
    
    '假設您休息時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [社群（Facebook、Instagram...）]': 'social_order_resting',
    '假設您休息時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [通訊（Line、Messenger...）]': 'communication_order_resting',
    '假設您休息時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [娛樂（遊戲、Netflix、YouTube...）]': 'entertainment_order_resting',
    '假設您休息時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [消息（新聞、信箱、天氣、運動）]': 'news_order_resting',
    '假設您休息時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [系統通知（軟體更新、容量已滿）]': 'system_order_resting',
    '假設您休息時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [提醒（鬧鈴、活動、待辦事項）]': 'notification_order_resting',
    
    '假設您通勤時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [社群（Facebook、Instagram...）]': 'social_order_commuting',
    '假設您通勤時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [通訊（Line、Messenger...）]': 'communication_order_commuting',
    '假設您通勤時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [娛樂（遊戲、Netflix、YouTube...）]': 'entertainment_order_commuting',
    '假設您通勤時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [消息（新聞、信箱、天氣、運動）]': 'news_order_commuting',
    '假設您通勤時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [系統通知（軟體更新、容量已滿）]': 'system_order_commuting',
    '假設您通勤時打開手機，若手機通知中心裡有六則通知，則您會希望下列6種通知類型的排序為何（通知中心由上至下為1-6）？（請左右滑動完整填寫每一項） [提醒（鬧鈴、活動、待辦事項）]': 'notification_order_commuting',

    '郵件信箱（通知中獎用）': 'email'
}, inplace=True)

print(main.columns)

supply.rename(columns={
    '時間戳記': 'timestamp',
    '您剛剛填寫的郵件信箱（對應舊問卷用）': 'email',
    '對各類應用程式每天的使用時長 [社群（Facebook、Instagram...）]': 'social_usetime',
    '對各類應用程式每天的使用時長 [通訊（Line、Messenger...）]': 'communication_usetime',
    '對各類應用程式每天的使用時長 [娛樂（遊戲、Netflix、YouTube...）]': 'entertainment_usetime',
    '對各類應用程式每天的使用時長 [消息（新聞、信箱、天氣、運動）]': 'news_usetime',
    '對各類應用程式每天的使用時長 [系統通知（軟體更新、容量已滿）]': 'system_usetime',
    '對各類應用程式每天的使用時長 [提醒（鬧鈴、活動、待辦事項）]': 'notification_usetime'
    }, inplace=True)
print(supply.columns)
# Out:
# Index(['timestamp', 'gender', 'age', 'department', 'total_usetime',
#        'social_usetime', 'communication_usetime', 'entertainment_usetime',
#        'news_usetime', 'system_usetime', 'notification_usetime',
#        'view_order_top', 'view_order_middle', 'view_order_bottom',
#        'social_order_wakingup', 'communication_order_wakingup',
#        'entertainment_order_wakingup', 'news_order_wakingup',
#        'system_order_wakingup', 'notification_order_wakingup',
#        'social_order_working', 'communication_order_working',
#        'entertainment_order_working', 'news_order_working',
#        'system_order_working', 'notification_order_working',
#        'social_order_resting', 'communication_order_resting',
#        'entertainment_order_resting', 'news_order_resting',
#        'system_order_resting', 'notification_order_resting',
#        'social_order_commuting', 'communication_order_commuting',
#        'entertainment_order_commuting', 'news_order_commuting',
# ...

# %%
# merge csv
for idx_s, row_s in supply.iterrows():
    for idx_m, row_m in main.iterrows():
        if type(row_m['email']) is str and row_m['email'].strip() == row_s['email'].strip():
            row_m['social_usetime'] = row_s['social_usetime']
            row_m['communication_usetime'] = row_s['communication_usetime']
            row_m['entertainment_usetime'] = row_s['entertainment_usetime']
            row_m['news_usetime'] = row_s['news_usetime']
            row_m['system_usetime'] = row_s['system_usetime']
            row_m['notification_usetime'] = row_s['notification_usetime']

# drop timestamp, email
main.drop(['timestamp', 'email'], axis=1, inplace=True)

# %%
# mappings
age_map = {
    '15歲以下': '0',
    '16～18歲': '1',
    '19～22歲': '2',
    '22～28歲': '3',
    '29歲以上': '4'
}
total_usetime_map = {
    '一小時以下': '0',
    '一至二小時': '1',
    '一至兩小時': '1',
    '二至三小時': '2',
    '三至四小時': '3',
    '五小時以上': '4'
}
partial_usetime_map = {
    '半小時以下': '0',
    '半至一小時': '1',
    '一至二小時': '2',
    '二至三小時': '3',
    '三小時以上': '4'
}
view_order_map = {
    '最先看': '1',
    '中': '2',
    '最後看': '3'
}
department_map = {
    "建國": "ot",
    "商學院 國貿系": "mg",
    "土木": "oe",
    "資料處理科": "cs",
    "數據所": "cs",
    "管理科學系": "mg",
    "護理科": "bi",
    "清大動機": "oe",
    "事業經營管理研究所": "mg",
    "醫學系": "bi",
    "材料": "oe",
    "機械": "oe",
    "工業管理科": "mg",
    "應用化學": "sc",
    "生命科學系": "bi",
    "生科系": "bi",
    "工科所": "oe",
    "教科系": "ed",
    "資財系": "cs",
    "歷史系": "lb",
    "地球科學": "sc",
    "機械系": "oe",
    "特教24": "ed",
    "机械系": "oe",
    "資工系": "cs",
    "電工系": "ee",
    "醫環系": "bi",
    "計財": "mg",
    "台大中文系畢業": "lb",
    "電機工程學系": "ee",
    "財金": "mg",
    "中文": "lb",
    "食品研究所": "sc",
    "交大應化系": "sc",
    "教育學院學士班": "ed",
    "工業工程": "mg",
    "材料系": "oe",
    "已畢業": "ot",
    "醫放系": "bi",
    "奈米學士班": "oe",
    "應用化學系": "sc",
    "英教系": "ed",
    "統計系": "lb",
    "應用統計": "lb",
    "原科院學士班": "sc",
    "清大心諮系": "lb",
    "工工系": "mg",
    "EE": "ee",
    "清大工工": "mg",
    "商學院": "mg",
    "金融所": "mg",
    "護理系": "bi",
    "法律系": "lb",
    "人社系": "lb",
    "服科所": "mg",
    "資訊工程系": "cs",
    "工科": "oe",
    "數學系": "sc",
    "材料系 ": "oe",
    "電機": "ee",
    "清華大學 工業工程與工程管理學系": "mg",
    "計財系": "mg",
    "醫學檢驗生物技術學系": "bi",
    "衛教係": "ed",
    "資工所": "cs",
    "電子物理系": "ee",
    "金融系": "mg",
    "電物": "ee",
    "傳播所": "oe",
    "材料23": "oe",
    "教育系": "ed",
    "資工": "cs",
    "工管系": "mg",
    "化工系": "oe",
    "電機系": "ee",
    "企業管理": "mg",
    "文資系": "lb",
    "國貿科": "mg",
    "工學院學士班": "oe",
    "電機所": "ee",
    "心諮系": "lb",
    "人社學士班": "lb",
    "資工11": "cs",
    "資訊工程學系": "cs",
    "人社": "lb",
    "化學": "sc",
    "中山大學化學系": "sc",
    "中文系": "lb",
    "機電系": "ee",
    "材料所": "oe",
    "醫管系": "bi",
    "特教23": "ed",
    "國小": "ot",
    "電資": "ee",
    "食品營養科": "sc",
    "外語": "lb",
    "無": "ot",
    "社畜": "ot",
    "物理系": "sc",
    "經濟": "mg",
    "會計系": "mg",
    "經濟系": "mg",
    "工工": "mg",
    "衛教系": "ed",
    "電子資料處理": "cs",
    "行銷系": "mg",
    "不分系": "ot",
    "生醫所": "bi",
    "工管": "mg"
}


mapped = pd.DataFrame()
mapped['gender'] = main['gender'].apply(lambda x: 'F' if x == '女' else 'M')
mapped['age'] = main['age'].apply(lambda x: age_map[x])
mapped['department'] = main['department'].apply(lambda x: department_map[x] if department_map[x] else x) # Waiting for mapping
mapped['total_usetime'] = main['total_usetime'].apply(lambda x: total_usetime_map[x])
mapped['social_usetime'] = main['social_usetime'].apply(lambda x: partial_usetime_map.get(x, '?'))
mapped['communication_usetime'] = main['communication_usetime'].apply(lambda x: partial_usetime_map.get(x, '?'))
mapped['entertainment_usetime'] = main['entertainment_usetime'].apply(lambda x: partial_usetime_map.get(x, '?'))
mapped['news_usetime'] = main['news_usetime'].apply(lambda x: partial_usetime_map.get(x, '?'))
mapped['system_usetime'] = main['system_usetime'].apply(lambda x: partial_usetime_map.get(x, '?'))
mapped['notification_usetime'] = main['notification_usetime'].apply(lambda x: partial_usetime_map.get(x, '?'))
mapped['view_order_top'] = main['view_order_top'].apply(lambda x: view_order_map[x])
mapped['view_order_middle'] = main['view_order_middle'].apply(lambda x: view_order_map[x])
mapped['view_order_bottom'] = main['view_order_bottom'].apply(lambda x: view_order_map[x])
for col in main.columns[13:]:
    mapped[col] = main[col].apply(lambda x: str(x)[:1])

# %%
# split the senarios
scenarios = {}
for col in mapped.columns[:13]:
    scenarios[col] = []
scenarios['scenario'] = []
scenarios['tol_111111'] = []
scenarios['tol_1122'] = []
scenarios['tol_123'] = []
scenarios['tol_222'] = []
scenarios['tol_24'] = []
scenarios['tol_15'] = []

for idx, row in mapped.iterrows():
    for col in mapped.columns[:13]:
        scenarios[col].append(row[col])
        scenarios[col].append(row[col])
        scenarios[col].append(row[col])
        scenarios[col].append(row[col])
    scenarios['scenario'].extend(['wakingup', 'working', 'resting', 'commuting'])
    for postfix in ('_wakingup', '_working', '_resting', '_commuting'):
        tmp = [('s', row['social_order' + postfix]), ('c', row['communication_order' + postfix]), ('e', row['entertainment_order' + postfix]), ('w', row['news_order' + postfix]), ('y', row['system_order' + postfix]), ('n', row['notification_order' + postfix])]
        tmp = sorted(tmp, key=lambda x: x[1])
        tmp = [x[0] for x in tmp]
        scenarios['tol_111111'].append(''.join(tmp))
        scenarios['tol_1122'].append(''.join(tmp[0:2] + sorted(tmp[2:4]) + sorted(tmp[4:6])))
        scenarios['tol_123'].append(''.join([tmp[0]] + sorted(tmp[1:3]) + sorted(tmp[3:])))
        scenarios['tol_222'].append(''.join(sorted(tmp[0:2]) + sorted(tmp[2:4]) + sorted(tmp[4:6])))
        scenarios['tol_24'].append(''.join(sorted(tmp[0:2]) + sorted(tmp[2:6])))
        scenarios['tol_15'].append(''.join(sorted(tmp[0]) + sorted(tmp[1:6])))


scenarios = pd.DataFrame(scenarios)
scenarios_shuffled = scenarios.sample(frac=1).reset_index(drop=True)

# %%
scenarios_shuffled.to_csv('notification_sequence.csv', index=False)
scenarios.to_csv('notification_sequence_unshuffled.csv', index=False)
